# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import PowerTransformer, StandardScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
def plot(df):
    l=[]
    s=0
    for i in df.columns:
        c=df[i].isnull().sum()
        if c>0:
            s+=1
            l.append(i)
    fig, axis = plt.subplots(figsize=(10, 3*s),nrows=s, ncols=2)
    axis=axis.flatten()
    for i in range(len(l)):
        if df[l[i]].nunique()<6:
            sns.kdeplot(df,x='SalePrice',hue=l[i],ax=axis[2*i+1])
        sns.scatterplot(df, x=l[i],y='SalePrice', ax=axis[2*i])
    plt.tight_layout()
# plot(df)

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#         Id  LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0        1         65.0     8450       2003          2003       196.0
# 1        2         80.0     9600       1976          1976         0.0
# 2        3         68.0    11250       2001          2002       162.0
# 3        4         60.0     9550       1915          1970         0.0
# 4        5         84.0    14260       2000          2000       350.0
# ...    ...          ...      ...        ...           ...         ...
# 1455  1456         62.0     7917       1999          2000         0.0
# 1456  1457         85.0    13175       1978          1988       119.0
# 1457  1458         66.0     9042       1941          2006         0.0
# 1458  1459         68.0     9717       1950          1996         0.0
# 1459  1460         75.0     9937       1965          1965         0.0
#
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  LowQualFinSF  \
# 0            706           0        150          856  ...             0
# 1            978           0        284         1262  ...             0
# 2            486           0        434          920  ...             0
# 3            216           0        540          756  ...             0
# 4            655           0        490         1145  ...             0
# ...          ...         ...        ...          ...  ...           ...
# 1455           0           0        953          953  ...             0
# 1456         790         163        589         1542  ...             0
# 1457         275           0        877         1152  ...             0
# 1458          49        1029          0         1078  ...             0
# 1459         830         290        136         1256  ...             0
#
#       GrLivArea  GarageYrBlt  GarageArea  WoodDeckSF  OpenPorchSF  \
# 0          1710       2003.0         548           0           61
# 1          1262       1976.0         460         298            0
# 2          1786       2001.0         608           0           42
# 3          1717       1998.0         642           0           35
# 4          2198       2000.0         836         192           84
# ...         ...          ...         ...         ...          ...
# 1455       1647       1999.0         460           0           40
# 1456       2073       1978.0         500         349            0
# 1457       2340       1941.0         252           0           60
# 1458       1078       1950.0         240         366            0
# 1459       1256       1965.0         276         736           68
#
#       EnclosedPorch  ScreenPorch  MiscVal  SalePrice
# 0                 0            0        0     208500
# 1                 0            0        0     181500
# 2                 0            0        0     223500
# 3               272            0        0     140000
# 4                 0            0        0     250000
# ...             ...          ...      ...        ...
# 1455              0            0        0     175000
# 1456              0            0        0     210000
# 1457              0            0     2500     266500
# 1458            112            0        0     142125
# 1459              0            0        0     147500
#
# [1460 rows x 22 columns]

# %%
pt = PowerTransformer()
sc = StandardScaler()
def BsmtExposure_map(v):
    if v=='Gd':
        return 4
    elif v== 'Av':
        return 3
    elif v=='Mn':
        return 2
    elif v=='No':
        return 1
    else:
        return 0
def BsmtFinType_map(f):
    if f=='GLQ':
        return 6
    elif f=='ALQ':
        return 5
    elif f=='BLQ':
        return 4
    elif f=='Rec':
        return 3
    elif f=='LwQ':
        return 2
    elif f=='Unf':
        return 1
    else:
        return 0
    
def garage_finish_map(v):
    if v=='Fin':
        return 3
    elif v== 'RFn':
        return 2
    elif v=='Unf':
        return 1
    else:
        return 0

def map_fill(f):
    if f=='Ex':
        return 5
    elif f=='Gd':
        return 4
    elif f=='TA':
        return 3
    elif f=='Fa':
        return 2
    elif f=='Po':
        return 1
    else:
        return 0
def Alley_map(v):
    if v=='Pave':
        return 2
    elif v == 'Grvl':
        return 1
    else:
        return 0

def clean(df):
    df.drop(['PoolQC','MiscFeature', 'Fence','GarageCars',
             'GarageCond','Utilities','Id',
              'Condition1', 'Exterior1st','SalePrice'], 
            axis=1, inplace = True, errors= 'ignore')
    df['BsmtQual'] = df['BsmtQual'].apply(map_fill)
    df['BsmtCond'] = df['BsmtCond'].apply(map_fill)
    df['FireplaceQu']= df['FireplaceQu'].apply(map_fill)
    df['GarageQual'] = df['GarageQual'].apply(map_fill)
    df['ExterQual'] = df['ExterQual'].apply(map_fill)
    df['ExterCond'] = df['ExterCond'].apply(map_fill)
    df['HeatingQC'] = df['HeatingQC'].apply(map_fill)
    df['KitchenQual'] = df['KitchenQual'].apply(map_fill)
    df['BsmtFinType2'] = df['BsmtFinType2'].apply(BsmtFinType_map)
    df['BsmtFinType1'] = df['BsmtFinType1'].apply(BsmtFinType_map)
    df['BsmtExposure'] = df['BsmtExposure'].apply(BsmtExposure_map)
    df['GarageFinish']= df['GarageFinish'].apply(garage_finish_map)
    df.LotFrontage.interpolate('linear',inplace=True)
    df.GarageYrBlt.interpolate('linear',inplace=True)
    df.MasVnrArea.interpolate('linear',inplace=True)
    df.LotFrontage.interpolate('linear',inplace=True)
    df = pd.get_dummies(df, columns=['GarageType','Alley', 'MasVnrType'], 
                        drop_first=False, dtype='int')
    df = pd.get_dummies(df, columns=['MSZoning', 'LotShape', 'LandContour',
                                     'LotConfig','LandSlope','Neighborhood', 
                                    'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle',
                                    'RoofMatl', 'Exterior2nd', 'Foundation',
                                    'Heating', 'CentralAir', 'Electrical', 'Functional', 
                                     'PavedDrive', 'SaleType','SaleCondition','Street'],
                        drop_first = True, dtype='int')
    cont = df.select_dtypes(include =['int','float'])
    l_cont =[]
    for i in cont.columns:
        n = cont[i].nunique()
        if n is n>20:
            l_cont.append(i)
    column = df.columns
    df[l_cont]=pt.fit_transform(df[l_cont])
    df = pd.DataFrame(df,columns = column)
    return df

# %%
df = pd.read_csv('train.csv')
y = df['SalePrice']
X = clean(df)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.LotFrontage.interpolate('linear',inplace=True)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:79: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.GarageYrBlt.interpolate('linear',inplace=True)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:80: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.MasVnrArea.interpolate('linear',inplace=True)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:81: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.LotFrontage.interpolate('linear',inplace=True)
# C:\Users\tbaka\anaconda3\Lib\site-packages\numpy\core\_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# LinearRegression()

# %%
pred = lr.predict(X_test)
mean_squared_error(pred, y_test)
# Out:
# 1820761753.0711393

# %%
r2_score(pred,y_test)
# Out:
# 0.7177862657278804

# %%
df = pd.read_csv('train.csv')
Q1= np.percentile(df['SalePrice'],25)
Q3= np.percentile(df['SalePrice'],75)
IQR = Q3-Q1
min1 = Q1-(3/2)*IQR
max1= Q3+(3/2)*IQR
df_outliers = df[(df.SalePrice>=max1)]
df_normal = df[(df.SalePrice<max1)]
y = df_normal['SalePrice']
X = clean(df_normal)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)
lr = LinearRegression()
lr.fit(X_train,y_train)
pred = lr.predict(X_test)
mean_squared_error(pred, y_test)
# Out:
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['PoolQC','MiscFeature', 'Fence','GarageCars',
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BsmtQual'] = df['BsmtQual'].apply(map_fill)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BsmtCond'] = df['BsmtCond'].apply(map_fill)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FireplaceQu']= df['FireplaceQu'].apply(map_fill)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GarageQual'] = df['GarageQual'].apply(map_fill)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ExterQual'] = df['ExterQual'].apply(map_fill)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ExterCond'] = df['ExterCond'].apply(map_fill)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HeatingQC'] = df['HeatingQC'].apply(map_fill)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['KitchenQual'] = df['KitchenQual'].apply(map_fill)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BsmtFinType2'] = df['BsmtFinType2'].apply(BsmtFinType_map)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BsmtFinType1'] = df['BsmtFinType1'].apply(BsmtFinType_map)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BsmtExposure'] = df['BsmtExposure'].apply(BsmtExposure_map)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GarageFinish']= df['GarageFinish'].apply(garage_finish_map)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.LotFrontage.interpolate('linear',inplace=True)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.LotFrontage.interpolate('linear',inplace=True)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:79: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.GarageYrBlt.interpolate('linear',inplace=True)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.GarageYrBlt.interpolate('linear',inplace=True)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:80: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.MasVnrArea.interpolate('linear',inplace=True)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.MasVnrArea.interpolate('linear',inplace=True)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:81: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.LotFrontage.interpolate('linear',inplace=True)
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_1964\3111299841.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.LotFrontage.interpolate('linear',inplace=True)
# C:\Users\tbaka\anaconda3\Lib\site-packages\numpy\core\_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# 657090563.5514795

# %%
657090563.5514795<1820761753.0711393
# Out:
# True

# %%
r2_score(pred,y_test)
# Out:
# 0.8339679129107656
